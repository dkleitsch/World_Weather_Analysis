# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
# Import the time library and datetime module from the datetime library
import time
from datetime import datetime
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?&units=Imperial&appid=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | santa luzia
# Processing Record 3 of Set 1 | bosaso
# Processing Record 4 of Set 1 | almaznyy
# Processing Record 5 of Set 1 | vostok
# Processing Record 6 of Set 1 | sayyan
# Processing Record 7 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | mehamn
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | lodja
# Processing Record 13 of Set 1 | karratha
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | grande-riviere
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | lovozero
# Processing Record 20 of Set 1 | ostrovnoy
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | laguna
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | vila velha
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | broken hill
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | kadyy
# Processing Record 34 of Set 1 | pitimbu
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | yatou
# Processing Record 37 of Set 1 | sao joao da barra
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | tura
# Processing Record 41 of Set 1 | de-kastri
# Processing Record 42 of Set 1 | san isidro
# Processing Record 43 of Set 1 | guerrero negro
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | mahina
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | aykhal
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | oranjemund
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | sao filipe
# Processing Record 4 of Set 2 | san benito
# Processing Record 5 of Set 2 | fort nelson
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | provideniya
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | usak
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | talara
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | samarai
# Processing Record 17 of Set 2 | bukoba
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | bemidji
# Processing Record 21 of Set 2 | witu
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | bredasdorp
# Processing Record 24 of Set 2 | tambura
# Processing Record 25 of Set 2 | miri
# Processing Record 26 of Set 2 | mount gambier
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | kieta
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | tongchuan
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | ballina
# Processing Record 34 of Set 2 | hinatuan
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | formosa
# Processing Record 38 of Set 2 | deputatskiy
# Processing Record 39 of Set 2 | sola
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | aromashevo
# Processing Record 42 of Set 2 | balimo
# City not found. Skipping...
# Processing Record 43 of Set 2 | srednekolymsk
# Processing Record 44 of Set 2 | nam tha
# City not found. Skipping...
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | powell
# Processing Record 47 of Set 2 | prince rupert
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | lorengau
# Processing Record 50 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 3 | fairbanks
# Processing Record 2 of Set 3 | mokolo
# Processing Record 3 of Set 3 | bengkulu
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | huarmey
# Processing Record 6 of Set 3 | quimper
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | lamu
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | ust-maya
# Processing Record 12 of Set 3 | bacolod
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | vigrestad
# Processing Record 15 of Set 3 | binzhou
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | indramayu
# Processing Record 18 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 3 | saundatti yellamma
# City not found. Skipping...
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | omemee
# Processing Record 23 of Set 3 | meybod
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | lata
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | huamachuco
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | tessalit
# Processing Record 31 of Set 3 | bedele
# Processing Record 32 of Set 3 | paramonga
# Processing Record 33 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | noumea
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | cairns
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | gualaceo
# Processing Record 41 of Set 3 | lobito
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | taveta
# Processing Record 44 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 3 | helena
# Processing Record 46 of Set 3 | kawalu
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | torbay
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | kirensk
# Processing Record 3 of Set 4 | tumut
# Processing Record 4 of Set 4 | morondava
# Processing Record 5 of Set 4 | shenjiamen
# Processing Record 6 of Set 4 | kudat
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | barrow
# Processing Record 9 of Set 4 | leningradskiy
# Processing Record 10 of Set 4 | chapais
# Processing Record 11 of Set 4 | rio bueno
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | nizwa
# Processing Record 14 of Set 4 | marsh harbour
# Processing Record 15 of Set 4 | nalut
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | auki
# Processing Record 19 of Set 4 | la ronge
# Processing Record 20 of Set 4 | zachagansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | maridi
# Processing Record 23 of Set 4 | belyy yar
# Processing Record 24 of Set 4 | praia
# Processing Record 25 of Set 4 | hohhot
# Processing Record 26 of Set 4 | gaoual
# Processing Record 27 of Set 4 | kahului
# Processing Record 28 of Set 4 | cayenne
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | salalah
# Processing Record 31 of Set 4 | nanga eboko
# Processing Record 32 of Set 4 | rodrigues alves
# Processing Record 33 of Set 4 | nyrob
# Processing Record 34 of Set 4 | vanino
# Processing Record 35 of Set 4 | dicabisagan
# Processing Record 36 of Set 4 | canico
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | shahrud
# Processing Record 39 of Set 4 | chitral
# Processing Record 40 of Set 4 | ajaccio
# Processing Record 41 of Set 4 | olinda
# Processing Record 42 of Set 4 | champerico
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | tiznit
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | port elizabeth
# Processing Record 47 of Set 4 | sur
# Processing Record 48 of Set 4 | adrar
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | mpulungu
# Processing Record 1 of Set 5 | middletown
# Processing Record 2 of Set 5 | pasni
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | cherskiy
# Processing Record 5 of Set 5 | ubinskoye
# Processing Record 6 of Set 5 | diffa
# Processing Record 7 of Set 5 | moron
# Processing Record 8 of Set 5 | roald
# Processing Record 9 of Set 5 | chara
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | ustka
# Processing Record 12 of Set 5 | clarksburg
# Processing Record 13 of Set 5 | chuy
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | clyde river
# Processing Record 16 of Set 5 | sheridan
# Processing Record 17 of Set 5 | buckeye
# Processing Record 18 of Set 5 | koungheul
# Processing Record 19 of Set 5 | caconda
# Processing Record 20 of Set 5 | tigil
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | comal
# Processing Record 27 of Set 5 | santa marta
# Processing Record 28 of Set 5 | san miguel
# Processing Record 29 of Set 5 | stephenville
# Processing Record 30 of Set 5 | acarau
# Processing Record 31 of Set 5 | mitu
# Processing Record 32 of Set 5 | bang saphan
# Processing Record 33 of Set 5 | tutoia
# Processing Record 34 of Set 5 | japura
# Processing Record 35 of Set 5 | gorom-gorom
# Processing Record 36 of Set 5 | bontang
# Processing Record 37 of Set 5 | xining
# Processing Record 38 of Set 5 | aketi
# Processing Record 39 of Set 5 | abha
# Processing Record 40 of Set 5 | haines junction
# Processing Record 41 of Set 5 | madhupur
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | quelimane
# Processing Record 44 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 5 | zhigansk
# Processing Record 46 of Set 5 | shahr-e babak
# Processing Record 47 of Set 5 | khani
# Processing Record 48 of Set 5 | nuristan
# Processing Record 49 of Set 5 | sorong
# Processing Record 50 of Set 5 | jitra
# Processing Record 1 of Set 6 | katha
# City not found. Skipping...
# Processing Record 2 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 6 | vero beach
# Processing Record 4 of Set 6 | mount isa
# Processing Record 5 of Set 6 | zhuanghe
# Processing Record 6 of Set 6 | mayo
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | qasigiannguit
# Processing Record 9 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 6 | vestmannaeyjar
# Processing Record 11 of Set 6 | jamame
# Processing Record 12 of Set 6 | oblivskaya
# Processing Record 13 of Set 6 | guatire
# Processing Record 14 of Set 6 | castro
# Processing Record 15 of Set 6 | dingle
# Processing Record 16 of Set 6 | banjar
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | gazanjyk
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | necochea
# Processing Record 21 of Set 6 | kundiawa
# Processing Record 22 of Set 6 | dongsheng
# Processing Record 23 of Set 6 | catuday
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 6 | bairiki
# Processing Record 28 of Set 6 | sinnamary
# Processing Record 29 of Set 6 | ribeira grande
# Processing Record 30 of Set 6 | umtata
# Processing Record 31 of Set 6 | tasiilaq
# Processing Record 32 of Set 6 | saint-philippe
# Processing Record 33 of Set 6 | viking
# Processing Record 34 of Set 6 | nemuro
# Processing Record 35 of Set 6 | murray bridge
# Processing Record 36 of Set 6 | diamantino
# Processing Record 37 of Set 6 | waingapu
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | krasnoselkup
# Processing Record 40 of Set 6 | spirit river
# Processing Record 41 of Set 6 | ayan
# Processing Record 42 of Set 6 | umm lajj
# Processing Record 43 of Set 6 | vazhiny
# Processing Record 44 of Set 6 | richards bay
# Processing Record 45 of Set 6 | skiathos
# Processing Record 46 of Set 6 | yeppoon
# Processing Record 47 of Set 6 | kutum
# Processing Record 48 of Set 6 | husavik
# Processing Record 49 of Set 6 | bud
# Processing Record 50 of Set 6 | zhaoyuan
# Processing Record 1 of Set 7 | diapaga
# Processing Record 2 of Set 7 | neiafu
# Processing Record 3 of Set 7 | poya
# Processing Record 4 of Set 7 | klyuchi
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | havre-saint-pierre
# Processing Record 7 of Set 7 | boguchany
# Processing Record 8 of Set 7 | mahon
# Processing Record 9 of Set 7 | fethiye
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | ahuimanu
# Processing Record 12 of Set 7 | pisco
# Processing Record 13 of Set 7 | touros
# Processing Record 14 of Set 7 | tupik
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | havoysund
# Processing Record 17 of Set 7 | abu kamal
# Processing Record 18 of Set 7 | nanakuli
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | kholm-zhirkovskiy
# Processing Record 21 of Set 7 | zuenoula
# Processing Record 22 of Set 7 | alappuzha
# Processing Record 23 of Set 7 | santa cruz
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | beloha
# Processing Record 26 of Set 7 | ilebo
# Processing Record 27 of Set 7 | petropavl
# Processing Record 28 of Set 7 | esperance
# Processing Record 29 of Set 7 | batagay
# Processing Record 30 of Set 7 | ust-ishim
# Processing Record 31 of Set 7 | pavlovskiy
# Processing Record 32 of Set 7 | tual
# Processing Record 33 of Set 7 | visnes
# Processing Record 34 of Set 7 | shima
# Processing Record 35 of Set 7 | lityn
# Processing Record 36 of Set 7 | valparaiso
# Processing Record 37 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 38 of Set 7 | paka
# Processing Record 39 of Set 7 | sandwick
# Processing Record 40 of Set 7 | leh
# Processing Record 41 of Set 7 | port-de-bouc
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | hay river
# Processing Record 45 of Set 7 | hai phong
# City not found. Skipping...
# Processing Record 46 of Set 7 | broome
# Processing Record 47 of Set 7 | wanaka
# Processing Record 48 of Set 7 | hovd
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | mahebourg
# Processing Record 1 of Set 8 | hobyo
# Processing Record 2 of Set 8 | la plata
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | dauriya
# Processing Record 7 of Set 8 | kaihua
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | ulaangom
# Processing Record 10 of Set 8 | alta floresta
# Processing Record 11 of Set 8 | westport
# Processing Record 12 of Set 8 | debre zeyit
# Processing Record 13 of Set 8 | dhidhdhoo
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | maslovskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | portland
# Processing Record 17 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | san quintin
# Processing Record 19 of Set 8 | yarada
# Processing Record 20 of Set 8 | dwarka
# Processing Record 21 of Set 8 | santa rosa
# Processing Record 22 of Set 8 | meulaboh
# Processing Record 23 of Set 8 | west bend
# Processing Record 24 of Set 8 | rorvik
# Processing Record 25 of Set 8 | nantucket
# Processing Record 26 of Set 8 | garowe
# Processing Record 27 of Set 8 | khorramshahr
# Processing Record 28 of Set 8 | lebanon
# Processing Record 29 of Set 8 | kushiro
# Processing Record 30 of Set 8 | uvinza
# Processing Record 31 of Set 8 | camacha
# Processing Record 32 of Set 8 | eydhafushi
# Processing Record 33 of Set 8 | burkburnett
# Processing Record 34 of Set 8 | lugus
# Processing Record 35 of Set 8 | praia da vitoria
# Processing Record 36 of Set 8 | vallenar
# Processing Record 37 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 8 | sakhnovshchyna
# Processing Record 39 of Set 8 | pangai
# Processing Record 40 of Set 8 | ojinaga
# Processing Record 41 of Set 8 | tevaitoa
# Processing Record 42 of Set 8 | chaa-khol
# City not found. Skipping...
# Processing Record 43 of Set 8 | nome
# Processing Record 44 of Set 8 | vitim
# Processing Record 45 of Set 8 | ancud
# Processing Record 46 of Set 8 | moindou
# Processing Record 47 of Set 8 | carballo
# Processing Record 48 of Set 8 | padang
# Processing Record 49 of Set 8 | nishihara
# Processing Record 50 of Set 8 | mandali
# Processing Record 1 of Set 9 | maneadero
# Processing Record 2 of Set 9 | andapa
# Processing Record 3 of Set 9 | las vegas
# Processing Record 4 of Set 9 | bambanglipuro
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | ponta delgada
# Processing Record 7 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 8 of Set 9 | porto walter
# Processing Record 9 of Set 9 | san cristobal
# Processing Record 10 of Set 9 | elizabeth city
# Processing Record 11 of Set 9 | xuddur
# Processing Record 12 of Set 9 | caravelas
# Processing Record 13 of Set 9 | ponoka
# Processing Record 14 of Set 9 | novyy urengoy
# Processing Record 15 of Set 9 | pinawa
# Processing Record 16 of Set 9 | wuhan
# Processing Record 17 of Set 9 | enfield
# Processing Record 18 of Set 9 | kimparana
# Processing Record 19 of Set 9 | kondinskoye
# Processing Record 20 of Set 9 | itarema
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | pimentel
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | sisophon
# Processing Record 25 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 26 of Set 9 | ulaanbaatar
# Processing Record 27 of Set 9 | eureka
# Processing Record 28 of Set 9 | mandiana
# Processing Record 29 of Set 9 | houma
# Processing Record 30 of Set 9 | mufumbwe
# Processing Record 31 of Set 9 | asosa
# Processing Record 32 of Set 9 | qui nhon
# Processing Record 33 of Set 9 | barcelona
# Processing Record 34 of Set 9 | bandar-e lengeh
# Processing Record 35 of Set 9 | honningsvag
# Processing Record 36 of Set 9 | dunedin
# Processing Record 37 of Set 9 | ergani
# Processing Record 38 of Set 9 | shimoda
# Processing Record 39 of Set 9 | rio tuba
# Processing Record 40 of Set 9 | hurricane
# Processing Record 41 of Set 9 | subate
# Processing Record 42 of Set 9 | nazilli
# Processing Record 43 of Set 9 | barao de melgaco
# Processing Record 44 of Set 9 | maningrida
# Processing Record 45 of Set 9 | ereymentau
# Processing Record 46 of Set 9 | severo-kurilsk
# Processing Record 47 of Set 9 | sambava
# Processing Record 48 of Set 9 | genhe
# Processing Record 49 of Set 9 | lhokseumawe
# Processing Record 50 of Set 9 | kaminoyama
# Processing Record 1 of Set 10 | kushima
# Processing Record 2 of Set 10 | aljezur
# Processing Record 3 of Set 10 | marsabit
# Processing Record 4 of Set 10 | nobres
# Processing Record 5 of Set 10 | zhuhai
# Processing Record 6 of Set 10 | camocim
# Processing Record 7 of Set 10 | fare
# Processing Record 8 of Set 10 | quepos
# Processing Record 9 of Set 10 | aklavik
# Processing Record 10 of Set 10 | axim
# Processing Record 11 of Set 10 | kotovo
# Processing Record 12 of Set 10 | shuya
# Processing Record 13 of Set 10 | half moon bay
# Processing Record 14 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 10 | hualmay
# Processing Record 16 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 17 of Set 10 | batagay-alyta
# Processing Record 18 of Set 10 | pimenta bueno
# Processing Record 19 of Set 10 | grindavik
# Processing Record 20 of Set 10 | bitung
# Processing Record 21 of Set 10 | kodinar
# Processing Record 22 of Set 10 | korla
# Processing Record 23 of Set 10 | uvalde
# Processing Record 24 of Set 10 | karangasem
# Processing Record 25 of Set 10 | saint-augustin
# Processing Record 26 of Set 10 | opuwo
# Processing Record 27 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 29 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 10 | andreyevo
# Processing Record 31 of Set 10 | tilichiki
# Processing Record 32 of Set 10 | meiganga
# Processing Record 33 of Set 10 | boguchar
# Processing Record 34 of Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 35 of Set 10 | nakasongola
# Processing Record 36 of Set 10 | port hawkesbury
# Processing Record 37 of Set 10 | nouadhibou
# Processing Record 38 of Set 10 | bismil
# Processing Record 39 of Set 10 | guder
# Processing Record 40 of Set 10 | phan thiet
# Processing Record 41 of Set 10 | shubarshi
# Processing Record 42 of Set 10 | bubaque
# Processing Record 43 of Set 10 | bukama
# Processing Record 44 of Set 10 | kirakira
# Processing Record 45 of Set 10 | ginda
# Processing Record 46 of Set 10 | lienz
# Processing Record 47 of Set 10 | waycross
# Processing Record 48 of Set 10 | joshimath
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | kangaatsiaq
# Processing Record 1 of Set 11 | lufilufi
# Processing Record 2 of Set 11 | manama
# Processing Record 3 of Set 11 | obo
# Processing Record 4 of Set 11 | urumqi
# Processing Record 5 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 6 of Set 11 | luorong
# Processing Record 7 of Set 11 | pitkyaranta
# Processing Record 8 of Set 11 | bara
# Processing Record 9 of Set 11 | dunkirk
# Processing Record 10 of Set 11 | cockburn town
# Processing Record 11 of Set 11 | zarubino
# Processing Record 12 of Set 11 | kyaikkami
# Processing Record 13 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 11 | lazurne
# Processing Record 15 of Set 11 | ulladulla
# Processing Record 16 of Set 11 | sisimiut
# Processing Record 17 of Set 11 | masoyila
# Processing Record 18 of Set 11 | rey bouba
# Processing Record 19 of Set 11 | pedasi
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | merauke
# Processing Record 22 of Set 11 | hailar
# Processing Record 23 of Set 11 | katsuura
# Processing Record 24 of Set 11 | ambovombe
# Processing Record 25 of Set 11 | lazaro cardenas
# Processing Record 26 of Set 11 | abakaliki
# Processing Record 27 of Set 11 | moose factory
# Processing Record 28 of Set 11 | sarkand
# Processing Record 29 of Set 11 | puerto baquerizo moreno
# Processing Record 30 of Set 11 | centralia
# Processing Record 31 of Set 11 | yerbogachen
# Processing Record 32 of Set 11 | vilhena
# Processing Record 33 of Set 11 | cap-aux-meules
# Processing Record 34 of Set 11 | udachnyy
# Processing Record 35 of Set 11 | kailua
# Processing Record 36 of Set 11 | matara
# Processing Record 37 of Set 11 | coos bay
# Processing Record 38 of Set 11 | colac
# Processing Record 39 of Set 11 | kalmunai
# Processing Record 40 of Set 11 | jalu
# Processing Record 41 of Set 11 | chipinge
# Processing Record 42 of Set 11 | vila
# Processing Record 43 of Set 11 | gazli
# Processing Record 44 of Set 11 | yar-sale
# Processing Record 45 of Set 11 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 46 of Set 11 | roebourne
# Processing Record 47 of Set 11 | cabedelo
# Processing Record 48 of Set 11 | sao gabriel da cachoeira
# Processing Record 49 of Set 11 | hun
# Processing Record 50 of Set 11 | inhambane
# Processing Record 1 of Set 12 | esso
# Processing Record 2 of Set 12 | gomel
# Processing Record 3 of Set 12 | olafsvik
# Processing Record 4 of Set 12 | smithers
# Processing Record 5 of Set 12 | quatre cocos
# Processing Record 6 of Set 12 | ahmadpur
# Processing Record 7 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 12 | antigonish
# Processing Record 9 of Set 12 | baruun-urt
# Processing Record 10 of Set 12 | mangrol
# Processing Record 11 of Set 12 | hervey bay
# Processing Record 12 of Set 12 | mezen
# Processing Record 13 of Set 12 | cazones
# Processing Record 14 of Set 12 | plouzane
# Processing Record 15 of Set 12 | lethem
# Processing Record 16 of Set 12 | kourou
# Processing Record 17 of Set 12 | noboribetsu
# Processing Record 18 of Set 12 | dharmanagar
# Processing Record 19 of Set 12 | grand-lahou
# Processing Record 20 of Set 12 | yanam
# Processing Record 21 of Set 12 | luganville
# Processing Record 22 of Set 12 | linxia
# Processing Record 23 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | west bay
# Processing Record 25 of Set 12 | borogontsy
# Processing Record 26 of Set 12 | kysyl-syr
# Processing Record 27 of Set 12 | anadyr
# Processing Record 28 of Set 12 | misratah
# Processing Record 29 of Set 12 | buchanan
# Processing Record 30 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 31 of Set 12 | beruni
# City not found. Skipping...
# Processing Record 32 of Set 12 | zhuzhou
# Processing Record 33 of Set 12 | filadelfia
# Processing Record 34 of Set 12 | chifeng
# Processing Record 35 of Set 12 | mranggen
# Processing Record 36 of Set 12 | cuamba
# Processing Record 37 of Set 12 | salamanca
# Processing Record 38 of Set 12 | naze
# Processing Record 39 of Set 12 | edgewater
# Processing Record 40 of Set 12 | liaqatabad
# Processing Record 41 of Set 12 | whitehorse
# Processing Record 42 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 43 of Set 12 | eyl
# Processing Record 44 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 12 | mitsamiouli
# Processing Record 46 of Set 12 | bathsheba
# Processing Record 47 of Set 12 | santa cruz de la palma
# Processing Record 48 of Set 12 | qesarya
# Processing Record 49 of Set 12 | szczecinek
# Processing Record 50 of Set 12 | dillon
# Processing Record 1 of Set 13 | tongzi
# Processing Record 2 of Set 13 | road town
# Processing Record 3 of Set 13 | santa cruz do capibaribe
# Processing Record 4 of Set 13 | celestun
# Processing Record 5 of Set 13 | isangel
# Processing Record 6 of Set 13 | marystown
# Processing Record 7 of Set 13 | makakilo city
# Processing Record 8 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 13 | esil
# Processing Record 10 of Set 13 | ituango
# Processing Record 11 of Set 13 | balkhash
# Processing Record 12 of Set 13 | huesca
# Processing Record 13 of Set 13 | syracuse
# Processing Record 14 of Set 13 | khuzhir
# Processing Record 15 of Set 13 | ishigaki
# Processing Record 16 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 18 of Set 13 | seymchan
# Processing Record 19 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 13 | howard springs
# Processing Record 21 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 22 of Set 13 | miyako
# Processing Record 23 of Set 13 | luyang
# Processing Record 24 of Set 13 | gat
# Processing Record 25 of Set 13 | port macquarie
# Processing Record 26 of Set 13 | kendallville
# Processing Record 27 of Set 13 | ketchikan
# Processing Record 28 of Set 13 | awbari
# Processing Record 29 of Set 13 | velykyy burluk
# Processing Record 30 of Set 13 | marienburg
# Processing Record 31 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 13 | kununurra
# Processing Record 33 of Set 13 | linqiong
# Processing Record 34 of Set 13 | nuuk
# Processing Record 35 of Set 13 | egvekinot
# Processing Record 36 of Set 13 | watsa
# Processing Record 37 of Set 13 | brekstad
# Processing Record 38 of Set 13 | nizhniy baskunchak
# Processing Record 39 of Set 13 | comodoro rivadavia
# Processing Record 40 of Set 13 | iquitos
# Processing Record 41 of Set 13 | katesh
# Processing Record 42 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 13 | lat yao
# Processing Record 44 of Set 13 | segou
# Processing Record 45 of Set 13 | saint anthony
# Processing Record 46 of Set 13 | tosya
# Processing Record 47 of Set 13 | luangwa
# Processing Record 48 of Set 13 | atar
# Processing Record 49 of Set 13 | waipawa
# Processing Record 50 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 1 of Set 14 | kuytun
# Processing Record 2 of Set 14 | ca mau
# Processing Record 3 of Set 14 | gilgit
# Processing Record 4 of Set 14 | volchanets
# Processing Record 5 of Set 14 | vasilyevo
# Processing Record 6 of Set 14 | nelson bay
# Processing Record 7 of Set 14 | port lincoln
# Processing Record 8 of Set 14 | otavi
# Processing Record 9 of Set 14 | nikolsk
# Processing Record 10 of Set 14 | abancay
# Processing Record 11 of Set 14 | barcelos
# Processing Record 12 of Set 14 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 14 | russkaya polyana
# Processing Record 14 of Set 14 | zalaegerszeg
# Processing Record 15 of Set 14 | marawi
# Processing Record 16 of Set 14 | zhangye
# Processing Record 17 of Set 14 | barraute
# Processing Record 18 of Set 14 | tukrah
# Processing Record 19 of Set 14 | lingao
# Processing Record 20 of Set 14 | nizhniy odes
# Processing Record 21 of Set 14 | svetlyy
# Processing Record 22 of Set 14 | ust-nera
# Processing Record 23 of Set 14 | nanchang
# Processing Record 24 of Set 14 | chiredzi
# Processing Record 25 of Set 14 | kyshtovka
# Processing Record 26 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 14 | iskateley
# Processing Record 28 of Set 14 | xam nua
# Processing Record 29 of Set 14 | pandan
# Processing Record 30 of Set 14 | coruripe
# Processing Record 31 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 14 | college
# Processing Record 33 of Set 14 | natal
# Processing Record 34 of Set 14 | louga
# Processing Record 35 of Set 14 | okha
# Processing Record 36 of Set 14 | fort wellington
# Processing Record 37 of Set 14 | isla mujeres
# Processing Record 38 of Set 14 | najran
# Processing Record 39 of Set 14 | novaya igirma
# Processing Record 40 of Set 14 | sechura
# Processing Record 41 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 14 | kerman
# Processing Record 43 of Set 14 | the valley
# Processing Record 44 of Set 14 | port hueneme
# Processing Record 45 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 47 of Set 14 | tagusao
# Processing Record 48 of Set 14 | hofn
# Processing Record 49 of Set 14 | kafue
# Processing Record 50 of Set 14 | langham
# Processing Record 1 of Set 15 | okhotsk
# Processing Record 2 of Set 15 | urengoy
# Processing Record 3 of Set 15 | kloulklubed
# Processing Record 4 of Set 15 | grand gaube
# Processing Record 5 of Set 15 | tikapur
# Processing Record 6 of Set 15 | antofagasta
# Processing Record 7 of Set 15 | constantine
# Processing Record 8 of Set 15 | loa janan
# Processing Record 9 of Set 15 | shingu
# Processing Record 10 of Set 15 | vardo
# Processing Record 11 of Set 15 | varangaon
# Processing Record 12 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 15 | kidal
# Processing Record 14 of Set 15 | thohoyandou
# Processing Record 15 of Set 15 | nara
# Processing Record 16 of Set 15 | rudbar
# Processing Record 17 of Set 15 | beira
# Processing Record 18 of Set 15 | khartoum
# Processing Record 19 of Set 15 | kargasok
# Processing Record 20 of Set 15 | amarante do maranhao
# Processing Record 21 of Set 15 | araguaina
# Processing Record 22 of Set 15 | moosomin
# Processing Record 23 of Set 15 | marfino
# Processing Record 24 of Set 15 | la rioja
# Processing Record 25 of Set 15 | roches noires
# City not found. Skipping...
# Processing Record 26 of Set 15 | boyolangu
# Processing Record 27 of Set 15 | nogliki
# Processing Record 28 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 15 | harlingen
# Processing Record 30 of Set 15 | newport
# Processing Record 31 of Set 15 | sorland
# Processing Record 32 of Set 15 | ust-koksa
# Processing Record 33 of Set 15 | medea
# Processing Record 34 of Set 15 | ilhabela
# Processing Record 35 of Set 15 | ossora
# Processing Record 36 of Set 15 | mananjary
# Processing Record 37 of Set 15 | longhua
# Processing Record 38 of Set 15 | chiradzulu
# Processing Record 39 of Set 15 | armidale
# Processing Record 40 of Set 15 | butembo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 672

# %%
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hobart      AU -42.8794  147.3294     49.05        85          14
# 1    Santa Luzia      BR -19.7697  -43.8514     77.90        76          90
# 2         Bosaso      SO  11.2842   49.1816     75.63        72           1
# 3       Almaznyy      RU  48.0448   40.0450     42.94        99         100
# 4         Vostok      RU  46.4856  135.8833    -11.20        99         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 667    Mananjary      MG -21.2167   48.3333     75.92        92         100
# 668      Longhua      CN  23.6137  114.1919     48.42        91          99
# 669   Chiradzulu      MW -15.6746   35.1407     67.24        87          24
# 670     Armidale      AU -30.5167  151.6500     53.82        92          76
# 671      Butembo      CD   0.1500   29.2833     63.21        60         100
#
#      Wind Speed Current Description
# 0          1.01          few clouds
# 1          2.84          light rain
# 2          4.70           clear sky
# 3          7.20          light rain
# 4          4.27     overcast clouds
# ..          ...                 ...
# 667       11.81       moderate rain
# 668        4.21     overcast clouds
# 669        1.16          few clouds
# 670        7.02       broken clouds
# 671        2.59     overcast clouds
#
# [672 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
